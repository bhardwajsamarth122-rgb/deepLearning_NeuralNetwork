# %%
# !pip install tensorflow==2.15.0
# Out:
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp310-cp310-win_amd64.whl.metadata (3.6 kB)
# Collecting tensorflow-intel==2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_intel-2.15.0-cp310-cp310-win_amd64.whl.metadata (5.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=2.9.0 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading h5py-3.15.1-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting ml-dtypes~=0.2.0 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Collecting numpy<2.0.0,>=1.23.5 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\anaconda3\envs\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached protobuf-4.25.8-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in c:\anaconda3\envs\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\anaconda3\envs\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\anaconda3\envs\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.15.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading wrapt-1.14.2-cp310-cp310-win_amd64.whl.metadata (6.6 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading grpcio-1.76.0-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached google_auth-2.45.0-py2.py3-none-any.whl.metadata (6.8 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached google_auth_oauthlib-1.2.3-py3-none-any.whl.metadata (3.1 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\anaconda3\envs\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.32.5)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\anaconda3\envs\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.1.3)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached cachetools-6.2.4-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached google_auth-2.41.1-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda3\envs\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\envs\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda3\envs\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\envs\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2025.11.12)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\anaconda3\envs\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.45.1)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\anaconda3\envs\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.0.3)
# Downloading tensorflow-2.15.0-cp310-cp310-win_amd64.whl (2.1 kB)
# Downloading tensorflow_intel-2.15.0-cp310-cp310-win_amd64.whl (300.9 MB)
#    ---------------------------------------- 0.0/300.9 MB ? eta -:--:--
#    ---------------------------------------- 3.1/300.9 MB 30.7 MB/s eta 0:00:10
#    ---------------------------------------- 3.1/300.9 MB 30.7 MB/s eta 0:00:10
#    ---------------------------------------- 3.1/300.9 MB 30.7 MB/s eta 0:00:10
#    - -------------------------------------- 8.7/300.9 MB 10.1 MB/s eta 0:00:29
#    - -------------------------------------- 9.4/300.9 MB 10.7 MB/s eta 0:00:28
#    - -------------------------------------- 14.2/300.9 MB 11.1 MB/s eta 0:00:26
#    -- ------------------------------------- 17.8/300.9 MB 12.6 MB/s eta 0:00:23
#    -- ------------------------------------- 19.9/300.9 MB 11.8 MB/s eta 0:00:24
#    -- ------------------------------------- 20.4/300.9 MB 10.7 MB/s eta 0:00:27
#    --- ------------------------------------ 24.1/300.9 MB 11.8 MB/s eta 0:00:24
#    --- ------------------------------------ 25.2/300.9 MB 11.1 MB/s eta 0:00:25
#    --- ------------------------------------ 27.0/300.9 MB 10.6 MB/s eta 0:00:26
#    --- ------------------------------------ 28.3/300.9 MB 10.9 MB/s eta 0:00:26
#    ---- ----------------------------------- 30.4/300.9 MB 10.5 MB/s eta 0:00:26
#    ---- ----------------------------------- 32.5/300.9 MB 10.4 MB/s eta 0:00:26
#    ---- ----------------------------------- 33.3/300.9 MB 9.9 MB/s eta 0:00:28
#    ----- ---------------------------------- 39.6/300.9 MB 11.0 MB/s eta 0:00:24
#    ------ --------------------------------- 45.6/300.9 MB 12.0 MB/s eta 0:00:22
#    ------ --------------------------------- 51.9/300.9 MB 13.0 MB/s eta 0:00:20
#    ------- -------------------------------- 53.5/300.9 MB 13.2 MB/s eta 0:00:19
#    ------- -------------------------------- 53.5/300.9 MB 13.2 MB/s eta 0:00:19
#    ------- -------------------------------- 53.5/300.9 MB 13.2 MB/s eta 0:00:19
#    ------- -------------------------------- 53.5/300.9 MB 13.2 MB/s eta 0:00:19
#    ------- -------------------------------- 56.6/300.9 MB 11.2 MB/s eta 0:00:22
#    ------- -------------------------------- 58.7/300.9 MB 11.4 MB/s eta 0:00:22
#    -------- ------------------------------- 64.0/300.9 MB 11.6 MB/s eta 0:00:21
#    --------- ------------------------------ 68.2/300.9 MB 12.1 MB/s eta 0:00:20
#    --------- ------------------------------ 70.8/300.9 MB 12.0 MB/s eta 0:00:20
#    ---------- ----------------------------- 76.5/300.9 MB 12.6 MB/s eta 0:00:18
#    ---------- ----------------------------- 77.3/300.9 MB 12.2 MB/s eta 0:00:19
#    ---------- ----------------------------- 78.6/300.9 MB 12.3 MB/s eta 0:00:19
#    ---------- ----------------------------- 81.8/300.9 MB 12.2 MB/s eta 0:00:18
#    ----------- ----------------------------
google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
#
#    ----------------------------------------  0/30 [libclang]
#    ----------------------------------------  0/30 [libclang]
#    ----------------------------------------  0/30 [libclang]
#    ----------------------------------------  0/30 [libclang]
#    - --------------------------------------  1/30 [flatbuffers]
#    - --------------------------------------  1/30 [flatbuffers]
#    ---- -----------------------------------  3/30 [termcolor]
#    ----- ---------------------------------  4/30 [tensorflow-io-gcs-filesystem]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    ------ ---------------------------------  5/30 [tensorflow-estimator]
#    --------- ------------------------------  7/30 [pyasn1]
#    --------- ------------------------------  7/30 [pyasn1]
#    --------- ------------------------------  7/30 [pyasn1]
#    --------- ------------------------------  7/30 [pyasn1]
#    --------- ------------------------------  7/30 [pyasn1]
#    ---------- -----------------------------  8/30 [protobuf]
#    ---------- -----------------------------  8/30 [protobuf]
#    ---------- -----------------------------  8/30 [protobuf]
#    ---------- -----------------------------  8/30 [protobuf]
#    ---------- -----------------------------  8/30 [protobuf]
#    ---------- -----------------------------  8/30 [protobuf]
#    ---------- -----------------------------  8/30 [protobuf]
#    ---------- -----------------------------  8/30 [protobuf]
#    ---------- -----------------------------  8/30 [protobuf]
#    ---------- -----------------------------  8/30 [protobuf]
#    ------------ ---------------------------  9/30 [opt-einsum]
#    ------------ ---------------------------  9/30 [opt-einsum]
#    ------------ ---------------------------  9/30 [opt-einsum]
#    ------------ ---------------------------  9/30 [opt-einsum]
#    ------------- -------------------------- 10/30 [oauthlib]
#    ------------- -------------------------- 10/30 [oauthlib]
#    ------------- -------------------------- 10/30 [oauthlib]
#    ------------- -------------------------- 10/30 [oauthlib]
#    ------------- -------------------------- 10/30 [oauthlib]
#    ------------- -------------------------- 10/30 [oauthlib]
#    ------------- -------------------------- 10/30 [oauthlib]
#    ------------- -------------------------- 10/30 [oauthlib]
#    ------------- -------------------------- 10/30 [oauthlib]
#    ------------- -------------------------- 10/30 [oauthlib]
#    ------------- -------------------------- 10/30 [oauthlib]
#    ------------- -------------------------- 10/30 [oauthlib]
#   Attempting uninstall: numpy
#    ------------- -------------------------- 10/30 [oauthlib]
#     Found existing installation: numpy 2.2.6
#    ------------- -------------------------- 10/30 [oauthlib]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#     Uninstalling numpy-2.2.6:
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#       Successfully uninstalled numpy-2.2.6
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    -------------- ------------------------- 11/30 [numpy]
#    ---------------- ----------------------- 12/30 [markdown]
#    ---------------- ----------------------- 12/30 [markdown]
#    ---------------- ----------------------- 12/30 [markdown]
#    ---------------- ----------------------- 12/30 [markdown]
#    ---------------- ----------------------- 12/30 [markdown]
#    ---------------- ----------------------- 12/30 [markdown]
#    ---------------- ----------------------- 12/30 [markdown]
#    ---------------- ----------------------- 12/30 [markdown]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ----------------- ---------------------- 13/30 [keras]
#    ------------------ --------------------- 14/30 [grpcio]
#    ------------------ --------------------- 14/30 [grpcio]
#    ------------------ --------------------- 14/30 [grpcio]
#    ------------------ --------------------- 14/30 [grpcio]
#    ------------------ --------------------- 14/30 [grpcio]
#    ------------------ --------------------- 14/30 [grpcio]
#    ------------------ --------------------- 14/30 [grpcio]
#    ------------------ --------------------- 14/30 [grpcio]
#    ------------------ --------------------- 14/30 [grpcio]
#    ------------------ --------------------- 14/30 [grpcio]
#    ------------------ --------------------- 14/30 [grpcio]
#    -------------------- ------------------- 15/30 [google-pasta]
#    -------------------- ------------------- 15/30 [google-pasta]
#    -------------------- ------------------- 15/30 [google-pasta]
#    -------------------- ------------------- 15/30 [google-pasta]
#    -------------------- ------------------- 15/30 [google-pasta]
#    --------------------- ------------------ 16/30 [gast]
#    ---------------------- ----------------- 17/30 [cachetools]
#    ------------------------ --------------- 18/30 [astunparse]
#    ------------------------- -------------- 19/30 [absl-py]
#    ------------------------- -------------- 19/30 [absl-py]
#    ------------------------- -------------- 19/30 [absl-py]
#    ------------------------- -------------- 19/30 [absl-py]
#    ------------------------- -------------- 19/30 [absl-py]
#    -------------------------- ------------- 20/30 [rsa]
#    -------------------------- ------------- 20/30 [rsa]
#    -------------------------- ------------- 20/30 [rsa]
#    -------------------------- ------------- 20/30 [rsa]
#    -------------------------- ------------- 20/30 [rsa]
#    -------------------------- ------------- 20/30 [rsa]
#    -------------------------- ------------- 20/30 [rsa]
#    -------------------------- ------------- 20/30 [rsa]
#    ---------------------------- ----------- 21/30 [requests-oauthlib]
#    ---------------------------- ----------- 21/30 [requests-oauthlib]
#    ---------------------------- ----------- 21/30 [requests-oauthlib]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ----------------------------- ---------- 22/30 [pyasn1-modules]
#    ------------------------------ --------- 23/30 [ml-dtypes]
#    ------------------------------ --------- 23/30 [ml-dtypes]
#    ------------------------------ --------- 23/30 [ml-dtypes]
#    ------------------------------ --------- 23/30 [ml-dtypes]
#    -------------------------------- ------- 24/30 [h5py]
#    -------------------------------- ------- 24/30 [h5py]
#    -------------------------------- ------- 24/30 [h5py]
#    -------------------------------- ------- 24/30 [h5py]
#    -------------------------------- ------- 24/30 [h5py]
#    -------------------------------- ------- 24/30 [h5py]
#    -------------------------------- ------- 24/30 [h5py]
#    -------------------------------- ------- 24/30 [h5py]
#    -------------------------------- ------- 24/30 [h5py]
#    --------------------------------- ------ 25/30 [google-auth]
#    --------------------------------- ------ 25/30 [google-auth]
#    --------------------------------- ------ 25/30 [google-auth]
#    --------------------------------- ------ 25/30 [google-auth]
#    --------------------------------- ------ 25/30 [google-auth]
#    --------------------------------- ------ 25/30 [google-auth]
#    --------------------------------- ------ 25/30 [google-auth]
#    --------------------------------- ------ 25/30 [google-auth]
#    --------------------------------- ------ 25/30 [google-auth]
#    --------------------------------- ------ 25/30 [google-auth]
#    --------------------------------- ------ 25/30 [google-auth]
#    --------------------------------- ------ 25/30 [google-auth]
#    --------------------------------- ------ 25/30 [google-auth]
#    ---------------------------------- ----- 26/30 [google-auth-oauthlib]
#    ---------------------------------- ----- 26/30 [google-auth-oauthlib]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------ --- 27/30 [tensorboard]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
# ...
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ------------------------------------- -- 28/30 [tensorflow-intel]
#    ---------------------------------------- 30/30 [tensorflow]
#
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 cachetools-6.2.4 flatbuffers-25.12.19 gast-0.7.0 google-auth-2.41.1 google-auth-oauthlib-1.2.3 google-pasta-0.2.0 grpcio-1.76.0 h5py-3.15.1 keras-2.15.0 libclang-18.1.1 markdown-3.10 ml-dtypes-0.2.0 numpy-1.26.4 oauthlib-3.3.1 opt-einsum-3.4.0 protobuf-4.25.8 pyasn1-0.6.1 pyasn1-modules-0.4.2 requests-oauthlib-2.0.0 rsa-4.9.1 tensorboard-2.15.2 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-intel-2.15.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-3.2.0 wrapt-1.14.2

# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\anaconda3\envs\venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
### Sentence
sent = ['the glass of milik',
        'the glass of juice',
'the cupof tea',
'I am a good boy',
'I am a good developer',
'understanf the meaning of the word',
'your videos are good']

# %%
sent
# Out:
# ['the glass of milik',
#  'the glass of juice',
#  'the cupof tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understanf the meaning of the word',
#  'your videos are good']

# %%
## Define the vocabulary 
voc_size = 10000

# %%
sent

# %%
## One hot Representation 
one_hot_repr = [one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[2816, 3772, 5806, 804],
#  [2816, 3772, 5806, 5499],
#  [2816, 3776, 5415],
#  [6981, 7637, 3274, 7886, 7177],
#  [6981, 7637, 3274, 7886, 9618],
#  [1362, 2816, 8256, 5806, 2816, 1846],
#  [3651, 5084, 8743, 7886]]

# %%
## word Embedding Representation 

from tensorflow.keras.layers import Embedding
# from tensorflow.keras.processing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np
sent_length
# Out:
# 8

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr,padding='pre', maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 2816 3772 5806  804]
#  [   0    0    0    0 2816 3772 5806 5499]
#  [   0    0    0    0    0 2816 3776 5415]
#  [   0    0    0 6981 7637 3274 7886 7177]
#  [   0    0    0 6981 7637 3274 7886 9618]
#  [   0    0 1362 2816 8256 5806 2816 1846]
#  [   0    0    0    0 3651 5084 8743 7886]]

# %%
## feature representation
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse','accuracy')
# Out:
# WARNING:tensorflow:From c:\anaconda3\envs\venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\anaconda3\envs\venv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 437ms/step
# array([[[ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.04460254,  0.00099926,  0.03457827,  0.04976488,
#          -0.01882999,  0.0493764 , -0.03213118,  0.00617529,
#           0.03380967,  0.03095832],
#         [ 0.03632785, -0.02414423,  0.01229538,  0.00158978,
#           0.02757463, -0.00904034, -0.03547059,  0.0449481 ,
#           0.02391228, -0.01556274],
#         [-0.0204899 ,  0.02269932, -0.04457694,  0.0343783 ,
#          -0.00554664,  0.04108698,  0.00233023,  0.04122533,
#           0.03079844, -0.0378468 ],
#         [ 0.04584974,  0.02728138, -0.02585905,  0.03795407,
#          -0.00430221, -0.015345  , -0.04148225,  0.04803202,
#          -0.02462905, -0.03328049]],
#
#        [[ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.04460254,  0.00099926,  0.03457827,  0.04976488,
#          -0.01882999,  0.0493764 , -0.03213118,  0.00617529,
#           0.03380967,  0.03095832],
#         [ 0.03632785, -0.02414423,  0.01229538,  0.00158978,
#           0.02757463, -0.00904034, -0.03547059,  0.0449481 ,
#           0.02391228, -0.01556274],
#         [-0.0204899 ,  0.02269932, -0.04457694,  0.0343783 ,
#          -0.00554664,  0.04108698,  0.00233023,  0.04122533,
#           0.03079844, -0.0378468 ],
#         [ 0.03021054,  0.00264609, -0.02955149, -0.03496211,
#          -0.01716338, -0.00289603,  0.01352355, -0.04613004,
#           0.01803669, -0.03064309]],
#
#        [[ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.04460254,  0.00099926,  0.03457827,  0.04976488,
#          -0.01882999,  0.0493764 , -0.03213118,  0.00617529,
#           0.03380967,  0.03095832],
#         [-0.04668387,  0.0111201 ,  0.0452783 , -0.04843351,
#           0.00549565, -0.00758145, -0.04122414,  0.00464477,
#          -0.04027421,  0.02560453],
#         [ 0.04396016, -0.00066989, -0.03164264,  0.04562867,
#           0.00143003,  0.00599421, -0.02413051, -0.04833502,
#          -0.03692082,  0.01073933]],
#
#        [[ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [-0.00151696,  0.01863334,  0.02909884,  0.02130128,
#           0.01082151,  0.03213323, -0.02742877,  0.00664862,
#           0.01208832,  0.0172031 ],
#         [-0.00204213, -0.00187607,  0.00768801,  0.02463478,
#          -0.02555555,  0.0099444 , -0.00658242,  0.0170411 ,
#           0.03122934, -0.04821531],
#         [-0.0102964 , -0.04194304,  0.01930541,  0.00250984,
#           0.00155356,  0.02179548, -0.03816762, -0.0224521 ,
#           0.00962139,  0.00596547],
#         [-0.01473075,  0.01507313, -0.02628748, -0.04259003,
#           0.01273796, -0.00708066, -0.00531258,  0.0041752 ,
#           0.00615618, -0.02035921],
#         [ 0.03590424,  0.02451284, -0.03053567, -0.02775251,
#          -0.00735276, -0.03273036, -0.00021306,  0.0023919 ,
#          -0.02142086, -0.01376028]],
#
#        [[ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [-0.00151696,  0.01863334,  0.02909884,  0.02130128,
#           0.01082151,  0.03213323, -0.02742877,  0.00664862,
#           0.01208832,  0.0172031 ],
#         [-0.00204213, -0.00187607,  0.00768801,  0.02463478,
#          -0.02555555,  0.0099444 , -0.00658242,  0.0170411 ,
#           0.03122934, -0.04821531],
#         [-0.0102964 , -0.04194304,  0.01930541,  0.00250984,
#           0.00155356,  0.02179548, -0.03816762, -0.0224521 ,
#           0.00962139,  0.00596547],
#         [-0.01473075,  0.01507313, -0.02628748, -0.04259003,
#           0.01273796, -0.00708066, -0.00531258,  0.0041752 ,
#           0.00615618, -0.02035921],
#         [-0.01896801,  0.04248739,  0.01940105,  0.00624081,
#          -0.01427076,  0.0297913 , -0.02030225,  0.03286097,
#          -0.03787948,  0.02175127]],
#
#        [[ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.01958254,  0.02453278, -0.03872547,  0.02293671,
#           0.04095758,  0.01960203,  0.019393  , -0.02748904,
#          -0.0235401 ,  0.01811356],
#         [ 0.04460254,  0.00099926,  0.03457827,  0.04976488,
#          -0.01882999,  0.0493764 , -0.03213118,  0.00617529,
#           0.03380967,  0.03095832],
#         [ 0.03744403,  0.04931325,  0.00528129, -0.04415597,
#           0.01786257,  0.04008425, -0.04112563,  0.01748476,
#          -0.00297264,  0.02115332],
#         [-0.0204899 ,  0.02269932, -0.04457694,  0.0343783 ,
#          -0.00554664,  0.04108698,  0.00233023,  0.04122533,
#           0.03079844, -0.0378468 ],
#         [ 0.04460254,  0.00099926,  0.03457827,  0.04976488,
#          -0.01882999,  0.0493764 , -0.03213118,  0.00617529,
#           0.03380967,  0.03095832],
#         [-0.03820574, -0.03936272, -0.04056286,  0.00071847,
#           0.00556079, -0.02606984,  0.03885989, -0.00537797,
#           0.04854706,  0.01102237]],
#
#        [[ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,
#           0.02127234,  0.0178269 ,  0.01333163,  0.01183299,
#           0.00817551,  0.01402878],
#         [ 0.03833027, -0.04127032,  0.00418714,  0.00714278,
#           0.0449875 , -0.02269671,  0.00752561,  0.03623215,
#          -0.02428312,  0.04118507],
#         [ 0.02222231, -0.01358756,  0.0291318 ,  0.01592888,
#          -0.000306  , -0.03949864,  0.02676698, -0.04420486,
#          -0.0427794 , -0.03647643],
#         [ 0.01906072, -0.04845206, -0.02263584,  0.03210557,
#          -0.0252166 ,  0.03258762,  0.0487305 , -0.01351434,
#          -0.02932693,  0.04093225],
#         [-0.01473075,  0.01507313, -0.02628748, -0.04259003,
#           0.01273796, -0.00708066, -0.00531258,  0.0041752 ,
#           0.00615618, -0.02035921]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 2816, 3772, 5806,  804])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 57ms/step
# array([[ 0.02970829, -0.02430716,  0.00165607, -0.04275695,  0.02127234,
#          0.0178269 ,  0.01333163,  0.01183299,  0.00817551,  0.01402878],
#        [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,  0.02127234,
#          0.0178269 ,  0.01333163,  0.01183299,  0.00817551,  0.01402878],
#        [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,  0.02127234,
#          0.0178269 ,  0.01333163,  0.01183299,  0.00817551,  0.01402878],
#        [ 0.02970829, -0.02430716,  0.00165607, -0.04275695,  0.02127234,
#          0.0178269 ,  0.01333163,  0.01183299,  0.00817551,  0.01402878],
#        [ 0.04460254,  0.00099926,  0.03457827,  0.04976488, -0.01882999,
#          0.0493764 , -0.03213118,  0.00617529,  0.03380967,  0.03095832],
#        [ 0.03632785, -0.02414423,  0.01229538,  0.00158978,  0.02757463,
#         -0.00904034, -0.03547059,  0.0449481 ,  0.02391228, -0.01556274],
#        [-0.0204899 ,  0.02269932, -0.04457694,  0.0343783 , -0.00554664,
#          0.04108698,  0.00233023,  0.04122533,  0.03079844, -0.0378468 ],
#        [ 0.04584974,  0.02728138, -0.02585905,  0.03795407, -0.00430221,
#         -0.015345  , -0.04148225,  0.04803202, -0.02462905, -0.03328049]],
#       dtype=float32)
